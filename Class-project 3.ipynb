# %%
client_id = dbutils.secrets.get(scope="clientsecret", key="client-id-1")
client_secret = dbutils.secrets.get(scope="clientsecret", key="adls-client-secret")


configs = {"fs.azure.account.auth.type": "OAuth",
       "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
       "fs.azure.account.oauth2.client.id": client_id,
       "fs.azure.account.oauth2.client.secret": client_secret,
       "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/2b807a22-351e-4356-80e7-422eee60f84d/oauth2/token"
       }
dbutils.fs.mount(
source = "abfss://store-analytisc-data@adlsfordatabrickprojects.dfs.core.windows.net/",
mount_point = "/mnt/store-analytisc-data",
extra_configs = configs)
# Out:
# True

# %%
dbutils.fs.ls("/mnt/store-analytisc-data/bronze")
display(dbutils.fs.ls("/mnt/store-analytisc-data/bronze"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Read the bronze layer
# Read raw data from Bronze layer
df_transactions = spark.read.parquet('/mnt/store-analytisc-data/bronze/transaction.parquet/')
df_products = spark.read.parquet('/mnt/store-analytisc-data/bronze/product.parquet/')
df_shop = spark.read.parquet('/mnt/store-analytisc-data/bronze/store.parquet/') 

df_customers = spark.read.parquet('/mnt/store-analytisc-data/bronze/customer_analytics.parquet/')
display(df_customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_transactions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create silver layer - data cleaning

from pyspark.sql.functions import col

# Convert types and clean data
df_transactions = df_transactions.select(
    col("transaction_id").cast("int"),
    col("customer_id").cast("int"),
    col("product_id").cast("int"),
    col("store_id").cast("int"),
    col("quantity").cast("int"),
    col("transaction_date").cast("date")
)

# %%
df_products = df_products.select(
    col("product_id").cast("int"),
    col("product_name"),
    col("category"),
    col("price").cast("double")
)

# %%
df_shop = df_shop.select(
    col("store_id").cast("int"),
    col("store_name"),
    col("location")
)

# %%
df_customers = df_customers.select(
    "customer_id", "first_name", "last_name", "email", "city", "registration_date"
).dropDuplicates(["customer_id"])

# %%
# Join all data together

df_silver = df_transactions \
    .join(df_customers, "customer_id") \
    .join(df_products, "product_id") \
    .join(df_shop, "store_id") \
    .withColumn("total_amount", col("quantity") * col("price"))

# %%
display(df_silver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Copy to adls locatioN
silver_path = "/mnt/store-analytisc-data/silver/"

df_silver.write.mode("overwrite").format("delta").save(silver_path)

# %%
# Create silver dataset

spark.sql(f"""
CREATE TABLE store_silver_cleaned
USING DELTA
LOCATION 'abfss://store-analytisc-data@adlsfordatabrickprojects.dfs.core.windows.net/silver/'
""")
# Out:
# DataFrame[]

# %%
# %sql 
select * from store_silver_cleaned
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Load cleaned transactions from Silver layer
silver_df = spark.read.format("delta").load("/mnt/store-analytisc-data/silver/")

# %%
display(silver_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# CREATE THE GOLD DATAFRAME BY AGGREEGATING THE SILVER DATAFRAME ACCORDING TO THE REQUIREMENT

from pyspark.sql.functions import sum, countDistinct, avg

gold_df = silver_df.groupBy(
    "transaction_date",
    "product_id", "product_name", "category",
    "store_id", "store_name", "location"
).agg(
    sum("quantity").alias("total_quantity_sold"),
    sum("total_amount").alias("total_sales_amount"),
    countDistinct("transaction_id").alias("number_of_transactions"),
    avg("total_amount").alias("average_transaction_value")
)

# %%
# VALIDATE THE GOLD DATAFRAME

display(gold_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
gold_path = "/mnt/store-analytisc-data/gold/"

gold_df.write.mode("overwrite").format("delta").save(gold_path)

# %%
# CREATE A DATABRICKS TABLE USING SPARK SQL
# Create silver dataset
spark.sql(f"""
CREATE TABLE store_gold_sales_summary
USING DELTA
LOCATION 'abfss://store-analytisc-data@adlsfordatabrickprojects.dfs.core.windows.net/gold/' 
""")
# Out:
# DataFrame[]

# %%
# %sql 
select * from store_gold_sales_summary
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
